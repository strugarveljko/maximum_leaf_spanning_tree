# %%
# %run algorithm.ipynb

import matplotlib.pyplot as plt
import time

# %%
def test_graph(num_of_nodes=10, edge_existence_prob=0.3):

    G = nx.erdos_renyi_graph(num_of_nodes, edge_existence_prob)
    while not nx.is_connected(G):
        G = nx.erdos_renyi_graph(num_of_nodes, edge_existence_prob)
    
    print(f"\n\nTesting a graph of {num_of_nodes} nodes and {len(G.edges)} edges...\n")

    mst = nx.minimum_spanning_tree(G)
    
    start_time = time.time()
    tree, leaf_count = branch_and_bound_mlstp(G)
    end_time = time.time()

    elapsed_time = end_time - start_time
    minutes = int(elapsed_time // 60)
    seconds = int(elapsed_time % 60)
    milliseconds = int((elapsed_time * 1000) % 1000)
    
    print(f"Execution time: \t\t\t {minutes}m {seconds}s {milliseconds}ms")
    print(f'Number of leaves of a random MST: \t {count_leaves(mst)}')
    print(f'Number of leaves of MLST: \t\t {leaf_count}')
    
    node_colors = []
    for node in tree.nodes():
        if tree.degree[node] == 1:
            node_colors.append('red')
        else:
            node_colors.append('blue')
    
    _, axes = plt.subplots(1, 2, figsize=(10, 5))

    nx.draw(G, node_size=10000/num_of_nodes, ax=axes[0])
    axes[0].set_title("Original graph")

    nx.draw(tree.to_undirected(), node_color=node_colors, node_size=10000/num_of_nodes, ax=axes[1])
    axes[1].set_title("Maximum Leaf Spanning Tree")

    plt.tight_layout()
    plt.show()

# %%
test_graph(num_of_nodes=10, edge_existence_prob=0.2)
# Out:
# Testing a graph of 10 nodes and 10 edges...
#
# Execution time: 			 0m 0s 1ms
# Number of leaves of a random MST: 	 4
# Number of leaves of MLST: 		 5

# %%
test_graph(num_of_nodes=10, edge_existence_prob=0.5)
# Out:
# Testing a graph of 10 nodes and 21 edges...
#
# Execution time: 			 0m 0s 3ms
# Number of leaves of a random MST: 	 6
# Number of leaves of MLST: 		 7

# %%
test_graph(num_of_nodes=10, edge_existence_prob=0.7)
# Out:
# Testing a graph of 10 nodes and 30 edges...
#
# Execution time: 			 0m 0s 2ms
# Number of leaves of a random MST: 	 7
# Number of leaves of MLST: 		 8

# %%
test_graph(num_of_nodes=20, edge_existence_prob=0.2)
# Out:
# Testing a graph of 20 nodes and 41 edges...
#
# Execution time: 			 0m 0s 9ms
# Number of leaves of a random MST: 	 12
# Number of leaves of MLST: 		 13

# %%
test_graph(num_of_nodes=20, edge_existence_prob=0.5)
# Out:
# Testing a graph of 20 nodes and 82 edges...
#
# Execution time: 			 0m 0s 7ms
# Number of leaves of a random MST: 	 14
# Number of leaves of MLST: 		 17

# %%
test_graph(num_of_nodes=20, edge_existence_prob=0.7)
# Out:
# Testing a graph of 20 nodes and 130 edges...
#
# Execution time: 			 0m 0s 8ms
# Number of leaves of a random MST: 	 17
# Number of leaves of MLST: 		 18

# %%
test_graph(num_of_nodes=50, edge_existence_prob=0.2)
# Out:
# Testing a graph of 50 nodes and 230 edges...
#
# Execution time: 			 0m 0s 81ms
# Number of leaves of a random MST: 	 36
# Number of leaves of MLST: 		 39

# %%
test_graph(num_of_nodes=50, edge_existence_prob=0.5)
# Out:
# Testing a graph of 50 nodes and 636 edges...
#
# Execution time: 			 0m 0s 36ms
# Number of leaves of a random MST: 	 43
# Number of leaves of MLST: 		 45

# %%
test_graph(num_of_nodes=50, edge_existence_prob=0.7)
# Out:
# Testing a graph of 50 nodes and 840 edges...
#
# Execution time: 			 0m 0s 217ms
# Number of leaves of a random MST: 	 46
# Number of leaves of MLST: 		 48

# %%
test_graph(num_of_nodes=100, edge_existence_prob=0.2)
# Out:
# Testing a graph of 100 nodes and 981 edges...
#
# Execution time: 			 0m 0s 145ms
# Number of leaves of a random MST: 	 82
# Number of leaves of MLST: 		 88

# %%
test_graph(num_of_nodes=100, edge_existence_prob=0.5)
# Out:
# Testing a graph of 100 nodes and 2436 edges...
#
# Execution time: 			 0m 0s 139ms
# Number of leaves of a random MST: 	 94
# Number of leaves of MLST: 		 95

# %%
test_graph(num_of_nodes=100, edge_existence_prob=0.7)
# Out:
# Testing a graph of 100 nodes and 3456 edges...
#
# Execution time: 			 0m 0s 139ms
# Number of leaves of a random MST: 	 94
# Number of leaves of MLST: 		 97

# %%
test_graph(num_of_nodes=500, edge_existence_prob=0.2)
# Out:
# Testing a graph of 500 nodes and 24760 edges...
#
# Execution time: 			 0m 5s 657ms
# Number of leaves of a random MST: 	 478
# Number of leaves of MLST: 		 482

# %%
test_graph(num_of_nodes=500, edge_existence_prob=0.5)
# Out:
# Testing a graph of 500 nodes and 62495 edges...
#
# Execution time: 			 0m 5s 928ms
# Number of leaves of a random MST: 	 492
# Number of leaves of MLST: 		 493

# %%
test_graph(num_of_nodes=500, edge_existence_prob=0.7)
# Out:
# Testing a graph of 500 nodes and 87247 edges...
#
# Execution time: 			 0m 5s 707ms
# Number of leaves of a random MST: 	 494
# Number of leaves of MLST: 		 496

# %%
test_graph(num_of_nodes=1000, edge_existence_prob=0.2)
# Out:
# Testing a graph of 1000 nodes and 100019 edges...
#
# Execution time: 			 0m 28s 931ms
# Number of leaves of a random MST: 	 970
# Number of leaves of MLST: 		 977

# %%
test_graph(num_of_nodes=1000, edge_existence_prob=0.5)
# Out:
# Testing a graph of 1000 nodes and 249566 edges...
#
# Execution time: 			 0m 31s 54ms
# Number of leaves of a random MST: 	 988
# Number of leaves of MLST: 		 992

# %%
test_graph(num_of_nodes=1000, edge_existence_prob=0.7)
# Out:
# Testing a graph of 1000 nodes and 349747 edges...
#
# Execution time: 			 0m 32s 283ms
# Number of leaves of a random MST: 	 994
# Number of leaves of MLST: 		 995
